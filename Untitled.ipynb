# %%
import pandas as pd

df = pd.read_excel('SOCIOS OBREROS.xlsx',header=None)

# %%
def itert(df):
    for row in df.itertuples():
        ced = row[1]
        name = row[2]
        print(ced,name)
        
def locit(df):
    df1 = df.iloc[:,:2]
    for ced,name in df1.values:
        print(ced,name)
        
def locitx(df):
    df1 = df.iloc[:,[1,2]]
    for ced,name in df1.values:
        print(ced,name)

# %%
# %timeit locit(df)
# Out:
# 3147572 DOVAL MANUEL
# 614477 MONTAÑA Z ROQUE
# 627596 OROPEZA MARTINEZ JOSE ALBERTO
# 1875094 FERNANDEZ IDELFONZO
# 632919 RIVERO BOLIVAR PEDRO ANTONIO
# 3043553 REYES B RAFAEL V
# 3396383 ESCOBAR R. ANDRES A.
# 2152490 MADRID M JOSE A
# 12158273 SAN BLAS CUNTO AGUSTIN
# 6307046 CASTRO MARQUEZ ROLLMAN JOSE
# 1059570 FIGUEREDO R JESUS A
# 627829 RAMIREZ VICTOR BENILDE
# 4056366 SILVA M. MARCELO
# 6456886 SULBARAN  ZERPA MELANIO COLUMBO
# 4685253 RODRIGUEZ FUENTES JESUS RAFAEL
# 6118613 PERDOMO ANGEL HUMBERTO
# 617311 NIEVES TARSICIO JOSE
# 2691269 SOLORZANO GILBERTO
# 5708919 CARIACO RODRIGUEZ ANTONIO RAFAEL
# 3121905 ORTIZ R. LUIS M.
# 8679839 SANDOVAL BERROTERAN JESUS ALBERTO
# 6876431 BETANCOURT BELISARIO JOSE GREGORIO
# 11038429 MONTANA MANGARRET JOSE GREGORIO
# 6875881 NIEVES GONZALEZ GERMAN ENRIQUE
# 6850466 DELGADO INES RAMON
# 15519228 DIAZ RODRIGUEZ YEHINZON ISRAEL
# 4855712 CHIRINOS MARIO ANTONIO
# 6660612 ANDRADE ROMERO JOSE LUIS
# 6841378 NATERA PEROZO JOSE LUIS
# ...

# %%
# %timeit locitx(df)
# Out:
# DOVAL MANUEL 1140162781621107840
# MONTAÑA Z ROQUE 1140162721621117420
# OROPEZA MARTINEZ JOSE ALBERTO 1140162701621107867
# FERNANDEZ IDELFONZO 1140162711621107883
# RIVERO BOLIVAR PEDRO ANTONIO 1140162731621133396
# REYES B RAFAEL V 1140162711621119628
# ESCOBAR R. ANDRES A. 1140162731621107980
# MADRID M JOSE A 1140152031521240000
# SAN BLAS CUNTO AGUSTIN 1140162751621108030
# CASTRO MARQUEZ ROLLMAN JOSE 1140162741628000000
# FIGUEREDO R JESUS A 1140162771621107832
# RAMIREZ VICTOR BENILDE 1140162781621142328
# SILVA M. MARCELO 1140162721621107891
# SULBARAN  ZERPA MELANIO COLUMBO 140162701621107948
# RODRIGUEZ FUENTES JESUS RAFAEL 1140162761621128740
# PERDOMO ANGEL HUMBERTO 1140162711621107964
# NIEVES TARSICIO JOSE 1140162701621133000
# SOLORZANO GILBERTO 1140167811679007013
# CARIACO RODRIGUEZ ANTONIO RAFAEL 1140162741621107999
# ORTIZ R. LUIS M. 1140162711621135151
# SANDOVAL BERROTERAN JESUS ALBERTO 1140162711621131679
# ...
